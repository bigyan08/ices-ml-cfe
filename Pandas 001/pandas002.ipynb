# %%
import pandas as pd

# %% [markdown]
# ## Get the dataset

# %%
import kagglehub
path = kagglehub.dataset_download("gregorut/videogamesales")

# %%
path

# %%
# df = pd.read_csv('') include path here

# %% [markdown]
# ## Extracting Basic Information

# %%
# .head(),.sample(),.info(),etc

# %%
df.head()

# %% [markdown]
# ## Separating Columns

# %% [markdown]
# ### Numerical Columns

# %% [markdown]
# - .mean(), .min(), .max(), .std(), .std(),  etc
# - .corr() gives correlation between numerical variables
# - .describe() gives mean, max,.. in numerical columns

# %% [markdown]
# ### Categorical Columns

# %% [markdown]
# .describe() gives count,unique,top,freq in categorical columns

# %% [markdown]
# ## Applying functions

# %%
# .assign() -> helps to create new column

# %%
# add numbers from each column and store in new column

# %%
# apply lambda function

# %%
df.head()

# %% [markdown]
# ## Cleaning Data using pandas

# %%
# df['col'].str.strip() -> removes whitespaces , \n, \t ...
# df['col'].str.lower() -> lower cases the texts
# df['col'].replace(['NA','null','-'], np.nan) -> replaces a list of string with null values

# %%
df['Publisher'].str.lower()

# %%
df['Publisher'].str.strip().str.replace('//',' ').str.lower()

# %% [markdown]
# ## Rename Columns
# - using .rename

# %%
df.rename(
    columns={
        'Publisher': 'Published By'
    }
    ,inplace=True
)

# %%
df

# %% [markdown]
# ## Filling Null values

# %%
df.isnull().sum()

# %% [markdown]
# ### Fill Year

# %%
df['Year'].describe()

# %% [markdown]
# ### Fill Published By

# %%
df['Published By'].describe()
